# %% [markdown]
# # Machine Learning Pipeline 3: California Housing Regression
# ## Advanced Regression with Decision Trees & Comprehensive Hyperparameter Optimization
#
# ### 📚 What You'll Master:
# 1. **Large Dataset Handling** - Working with 20K+ samples efficiently
# 2. **Data Sampling** - Reducing computational complexity strategically
# 3. **Decision Tree Regression** - Non-linear pattern detection
# 4. **Advanced Hyperparameter Tuning** - Grid search with multiple parameters
# 5. **Model Performance Comparison** - Before vs. after optimization
# 6. **Real-World Applications** - Housing price prediction
#
# ### 🏠 Dataset Overview: California Housing Prices
# - **Type**: Regression problem (predicting house prices)
# - **Original Size**: 20,640 houses
# - **Features**: 8 housing characteristics
# - **Target**: Median house value (in $100,000s)
# - **Challenge**: Large dataset requiring efficient processing
#
# ### 🎯 Advanced Learning Objectives:
# 1. **Computational Efficiency** - Why and how to sample large datasets
# 2. **Decision Tree Regression** - When linear models aren't enough
# 3. **Systematic Optimization** - Professional hyperparameter tuning
# 4. **Model Interpretation** - Understanding tree-based decisions
# 5. **Performance Evaluation** - R² score for regression quality
#
# ### 🔬 Key Advanced Concepts:
# - **Data Sampling Strategy** - Maintaining data integrity while reducing size
# - **Regression Trees** - Splitting numerical targets
# - **Grid Search CV** - Cross-validated parameter optimization
# - **Overfitting in Trees** - Complexity vs. generalization trade-off
#
# ### 💼 Real-World Application:
# This pipeline mirrors actual industry practices for:
# - Real estate price prediction
# - Property valuation models
# - Investment analysis tools
# - Market trend analysis
#
# ---

# %% [markdown]
# ## 🔰 Complete Beginner's Guide to Machine Learning Concepts
#
# ### 🤔 What is Machine Learning? (Simple Explanation)
#
# Think of **Machine Learning** like teaching a computer to recognize patterns, just like how you learned to recognize faces:
#
# 1. **As a baby**: You saw many faces and learned what makes a face
# 2. **Growing up**: You got better at recognizing different people
# 3. **Now**: You can instantly recognize faces you've never seen before
#
# **Machine Learning works the same way**:
# 1. **Training**: Show the computer lots of examples
# 2. **Learning**: Computer finds patterns in the data
# 3. **Prediction**: Computer can make guesses about new, unseen data
#
# ### 🏠 Our Housing Price Example (Real-World Application)
#
# **The Problem**: You want to buy a house, but how do you know if the price is fair?
#
# **Traditional Approach**:
# - Look at location, size, age manually
# - Compare with similar houses
# - Make an educated guess
#
# **Machine Learning Approach**:
# - Collect data on 20,000+ houses
# - Let the computer find patterns between house features and prices
# - Use these patterns to predict prices for any new house
#
# ### 📊 Types of Machine Learning Problems
#
# #### **1. Regression (What we're doing here)**
# - **Goal**: Predict a **number** (like house price, temperature, salary)
# - **Examples**:
#   - House price: $250,000, $180,000, $420,000
#   - Stock price: $45.67, $89.23, $156.78
#   - Temperature: 25°C, 18°C, 32°C
#
# #### **2. Classification (Like the Iris notebook)**
# - **Goal**: Predict a **category** (like flower type, email spam/not spam)
# - **Examples**:
#   - Flower type: Setosa, Versicolor, Virginica
#   - Email: Spam, Not Spam
#   - Animal: Cat, Dog, Bird
#
# ### 🎯 Why Use Decision Trees for House Prices?
#
# **Simple Question-Based Logic** (like a flowchart):
# ```
# Is the house near the ocean?
# ├─ YES: Is it bigger than 2000 sq ft?
# │   ├─ YES: Price = $800,000
# │   └─ NO: Price = $600,000
# └─ NO: Is it in a good neighborhood?
#     ├─ YES: Price = $400,000
#     └─ NO: Price = $200,000
# ```
#
# **Why Decision Trees are Perfect for Beginners**:
# 1. **Easy to understand**: Just yes/no questions
# 2. **Visual**: You can draw the tree and see the logic
# 3. **No math required**: No complex equations to understand
# 4. **Handles different data types**: Numbers, categories, everything
#
# ---

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

# %% [markdown]
# ## 📚 Understanding Python Libraries (Complete Beginner's Guide)
#
# ### 🤔 What are Python Libraries?
#
# Think of **libraries** like toolboxes:
# - **Regular toolbox**: Has hammers, screwdrivers, wrenches for building
# - **Python library**: Has pre-written code for specific tasks
#
# **Why use libraries?**
# - Someone already wrote the code for complex tasks
# - You don't need to reinvent the wheel
# - Focus on your problem, not programming details
#
# ### 🔧 Each Library Explained in Simple Terms:
#
# #### **`seaborn as sns`** - The Artist's Toolbox 🎨
# - **What it does**: Makes beautiful charts and graphs
# - **Real-world analogy**: Like having a professional graphic designer
# - **Example use**: "Show me a pretty chart of house prices vs. size"
# - **Why 'sns'**: Shorter to type than 'seaborn' every time
#
# #### **`matplotlib.pyplot as plt`** - The Basic Drawing Tools ✏️
# - **What it does**: Creates basic plots and charts
# - **Real-world analogy**: Like having pencils, rulers, and graph paper
# - **Relationship**: Seaborn uses matplotlib underneath (prettier version)
# - **Example use**: "Draw a simple line graph"
#
# #### **`warnings`** - The Noise Filter 🔇
# - **What it does**: Controls warning messages
# - **Real-world analogy**: Like turning off annoying notification sounds
# - **`warnings.filterwarnings('ignore')`**: "Don't show me non-critical warnings"
# - **Why useful**: Keeps output clean and focused
#
# #### **`pandas as pd`** - The Excel Expert 📊
# - **What it does**: Handles data tables (like Excel spreadsheets)
# - **Real-world analogy**: Like having a super-powered Excel
# - **Key features**:
#   - Read data from files (CSV, Excel, etc.)
#   - Clean and organize data
#   - Calculate statistics
#   - Filter and sort data
# - **Why 'pd'**: Standard abbreviation everyone uses
#
# ### 💡 Beginner Tips:
#
# 1. **Import at the top**: Always import libraries before using them
# 2. **Standard abbreviations**: Use 'pd' for pandas, 'plt' for matplotlib - everyone does this
# 3. **One import per line**: Easier to read and debug
# 4. **Don't worry about memorizing**: You'll remember with practice
#
# ### 🎯 What We'll Use Each Library For:
#
# - **pandas**: Load house data, organize it in tables
# - **matplotlib**: Create basic charts
# - **seaborn**: Make beautiful visualizations
# - **warnings**: Keep output clean

# %%
from sklearn.datasets import fetch_california_housing
data=fetch_california_housing()

# %% [markdown]
# ## 🏠 Loading Real Housing Data (Step-by-Step Explanation)
#
# ### 🤔 What is `fetch_california_housing`?
#
# **Simple explanation**: It's like having a pre-made dataset of California house information that scientists use for learning machine learning.
#
# **Real-world analogy**: Imagine you have a massive Excel file with information about 20,640 houses in California, including:
# - How big each house is
# - How old it is
# - Where it's located
# - How much it costs
#
# ### 📊 What's Inside This Dataset?
#
# #### **The Houses** (20,640 total):
# - Real houses from California (1990 census data)
# - Each row = one house
# - Each column = one piece of information about the house
#
# #### **The Information We Have** (8 features):
# 1. **MedInc**: Average income of people in the area
# 2. **HouseAge**: How old the house is
# 3. **AveRooms**: Average number of rooms
# 4. **AveBedrms**: Average number of bedrooms
# 5. **Population**: How many people live in the area
# 6. **AveOccup**: How many people per household
# 7. **Latitude**: North-South location (geography)
# 8. **Longitude**: East-West location (geography)
#
# #### **What We Want to Predict**:
# - **House Price**: The actual selling price of each house
#
# ### 🔍 Understanding the Code:
#
# ```python
# from sklearn.datasets import fetch_california_housing
# ```
# **Translation**: "Hey Python, I want to use the California housing dataset"
#
# ```python
# data = fetch_california_housing()
# ```
# **Translation**: "Go get the housing data and put it in a variable called 'data'"
#
# ### 🎯 Why This Dataset is Perfect for Learning:
#
# 1. **Real data**: Not made-up numbers, actual house information
# 2. **Clean data**: No missing information, ready to use
# 3. **Right size**: Big enough to be realistic, not too big to break your computer
# 4. **Understandable**: Everyone understands houses and prices
# 5. **Good for regression**: Predicting prices (numbers) instead of categories
#
# ### 💡 Beginner Insight:
# Think of `data` as a container with everything we need:
# - The house information (features)
# - The prices (target)
# - Descriptions of what everything means
# - Ready to use for machine learning!

# %%
df=pd.DataFrame(data.data,columns=data.feature_names)
df['Price']=data.target

# %% [markdown]
# ## 📊 Creating a Data Table (DataFrame Explained for Beginners)
#
# ### 🤔 What is a DataFrame?
#
# **Simple explanation**: A DataFrame is like an Excel spreadsheet in Python - it has rows and columns with data.
#
# **Visual analogy**:
# ```
# Excel Spreadsheet = DataFrame
# Rows = Houses (each house is one row)
# Columns = Features (age, size, price, etc.)
# ```
#
# ### 🔍 Understanding the Code Step-by-Step:
#
# #### **Step 1**: `pd.DataFrame(data.data, columns=data.feature_names)`
#
# **What this does**: Creates a table with house information
#
# **Breaking it down**:
# - `pd.DataFrame()`: "Create a data table"
# - `data.data`: The actual numbers (house measurements)
# - `columns=data.feature_names`: The column headers (what each measurement means)
#
# **Real-world analogy**:
# - You have a box of house information cards (data.data)
# - You have labels for organizing them (data.feature_names)
# - DataFrame puts them into a neat table
#
# #### **Step 2**: `df['Price'] = data.target`
#
# **What this does**: Adds the house prices as a new column
#
# **Breaking it down**:
# - `df['Price']`: "Create a new column called 'Price'"
# - `= data.target`: "Fill it with the actual house prices"
#
# ### 📋 What Our Table Looks Like Now:
#
# ```
# | MedInc | HouseAge | AveRooms | AveBedrms | Population | AveOccup | Latitude | Longitude | Price |
# |--------|----------|----------|-----------|------------|----------|----------|-----------|-------|
# | 8.3252 | 41.0     | 6.98     | 1.02      | 322.0      | 2.55     | 37.88    | -122.23   | 4.526 |
# | 8.3014 | 21.0     | 6.24     | 0.97      | 2401.0     | 2.11     | 37.86    | -122.22   | 3.585 |
# ```
#
# ### 🎯 Why Create a DataFrame?
#
# #### **Before (raw data)**:
# - Just numbers in arrays
# - Hard to understand what each number means
# - Difficult to explore and analyze
#
# #### **After (DataFrame)**:
# - Organized table with labeled columns
# - Easy to see what each number represents
# - Can easily sort, filter, and analyze
# - Can create charts and graphs
#
# ### 💡 Key Benefits for Beginners:
#
# 1. **Visual organization**: See your data like a spreadsheet
# 2. **Easy exploration**: Use `.head()` to see first few rows
# 3. **Simple operations**: Filter, sort, calculate statistics easily
# 4. **Direct plotting**: Create charts directly from the DataFrame
# 5. **Debugging**: Easier to spot problems in organized data
#
# ### 🔧 Common DataFrame Operations You'll Use:
# - `df.head()`: See first 5 rows
# - `df.shape`: See how many rows and columns
# - `df.info()`: Get summary information
# - `df.describe()`: Get statistics (mean, max, min, etc.)
#
# **Remember**: DataFrame = Your data organized like an Excel spreadsheet!

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Price
# ...

# %%
df.shape
# Out:
# (20640, 9)

# %%
#use less data as decision tree will else bewcome complex and take more time
df=df.sample(frac=0.40)

# %% [markdown]
# ## 📊 Strategic Data Sampling Theory
#
# ### 🤔 Why Sample Large Datasets?
#
# **Original Problem**:
# - **20,640 samples** = computationally expensive
# - **Decision trees** can become extremely complex
# - **Training time** increases exponentially with data size
# - **Memory usage** can become prohibitive
#
# ### 🎯 Sampling Strategy: 40% Random Sample
#
# **`df.sample(frac=0.40)`** explanation:
# - **`frac=0.40`**: Take 40% of original data (8,256 samples)
# - **Random sampling**: Maintains data distribution
# - **No bias**: Every sample has equal probability of selection
# - **Reproducible**: Set random_state for consistent results
#
# ### ⚖️ Trade-offs Analysis:
#
# #### **Benefits of Sampling**:
# 1. **Faster training**: 60% reduction in computation time
# 2. **Less memory**: Easier to handle on standard computers
# 3. **Simpler trees**: Reduces overfitting risk
# 4. **Faster experimentation**: Quick iteration during development
#
# #### **Potential Risks**:
# 1. **Information loss**: Might miss rare patterns
# 2. **Reduced accuracy**: Less data = potentially worse performance
# 3. **Representation bias**: Small chance of skewed sample
#
# ### 📈 When to Sample:
# - **Large datasets** (>10,000 samples)
# - **Initial exploration** and prototyping
# - **Limited computational resources**
# - **Quick model iteration** needed
#
# ### 🚫 When NOT to Sample:
# - **Small datasets** (<1,000 samples)
# - **Final production models**
# - **Rare event detection** (need all examples)
# - **When computational resources are abundant**
#
# ### 💡 Professional Practice:
# 1. **Start with sampling** for quick exploration
# 2. **Build final models** on full dataset
# 3. **Compare performance** between sampled and full data
# 4. **Document sampling decisions** for reproducibility
#
# ### 🔧 Alternative Sampling Methods:
# - **Stratified sampling**: Maintain class proportions
# - **Systematic sampling**: Every nth sample
# - **Cluster sampling**: Sample groups, not individuals

# %%
df.shape
# Out:
# (8256, 9)

# %% [markdown]
# ## 🔢 Understanding Data Sampling (Why Less Can Be More)
#
# ### 🤔 What Does `df.sample(frac=0.40)` Mean?
#
# **Simple explanation**: Take a random 40% of all the houses, like picking names from a hat.
#
# **Real-world analogy**:
# Imagine you want to know the average height of students in your school:
# - **Option 1**: Measure ALL 1,000 students (takes forever)
# - **Option 2**: Randomly pick 400 students and measure them (much faster, still accurate)
#
# ### 📊 The Numbers:
#
# #### **Before Sampling**:
# - **20,640 houses** = A LOT of data
# - **Takes long time** to process
# - **Uses lots of computer memory**
# - **Might crash your computer** if it's not powerful enough
#
# #### **After Sampling (40%)**:
# - **8,256 houses** = Much more manageable
# - **Faster processing** (less than half the time)
# - **Less memory usage** (fits on any computer)
# - **Still representative** of all California houses
#
# ### 🎯 Why 40%? (The Sweet Spot)
#
# #### **Too Little Data (10%)**:
# - ❌ Might miss important patterns
# - ❌ Results might not be accurate
# - ❌ Could be biased or unrepresentative
#
# #### **Too Much Data (80%)**:
# - ❌ Still slow to process
# - ❌ Doesn't solve the computational problem
# - ❌ Overkill for learning and experimentation
#
# #### **Just Right (40%)**:
# - ✅ Fast enough for quick experiments
# - ✅ Large enough to find real patterns
# - ✅ Good balance of speed and accuracy
# - ✅ Perfect for learning and development
#
# ### 🔍 How Random Sampling Works:
#
# ```python
# df.sample(frac=0.40)
# ```
#
# **Step-by-step process**:
# 1. **Python looks at all 20,640 houses**
# 2. **Randomly assigns each house a number**
# 3. **Picks the first 8,256 houses (40%)**
# 4. **Returns a new DataFrame with just those houses**
#
# **Key point**: Every house has an equal chance of being selected!
#
# ### 🎲 Why Random is Important:
#
# #### **Good (Random) Sampling**:
# - Expensive houses: 40% selected
# - Cheap houses: 40% selected
# - Big houses: 40% selected
# - Small houses: 40% selected
# - **Result**: Sample represents the whole dataset
#
# #### **Bad (Non-Random) Sampling**:
# - Taking only the first 8,256 houses
# - Could be biased (maybe all from one city)
# - Results wouldn't apply to all of California
#
# ### 💡 Professional Development Strategy:
#
# 1. **Start with a sample** (like 40%) for quick experimentation
# 2. **Test different algorithms** and parameters
# 3. **Once you find the best approach**, train on the full dataset
# 4. **Compare results** between sample and full data
#
# ### 🔧 Other Sampling Options:
#
# ```python
# df.sample(n=5000)          # Take exactly 5,000 houses
# df.sample(frac=0.25)       # Take 25% of houses
# df.sample(frac=0.60)       # Take 60% of houses
# df.sample(frac=0.40, random_state=42)  # Reproducible sampling
# ```
#
# **Remember**: Sampling is like taste-testing soup - you don't need to eat the whole pot to know if it's good!

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 15269  6.4247      14.0  6.560197   1.046683      1034.0  2.540541     33.07
# 6586   7.0059      39.0  6.681592   1.037313      1094.0  2.721393     34.22
# 18551  2.4250      28.0  4.174026   1.093506       926.0  2.405195     36.96
# 3614   3.1250      38.0  4.900000   1.010000       402.0  4.020000     34.24
# 19741  2.4555      15.0  6.177033   1.291866      1697.0  2.706539     39.90
# ...       ...       ...       ...        ...         ...       ...       ...
# 826    5.3644      36.0  6.305221   1.100402       992.0  3.983936     37.63
# 5341   2.1875      49.0  4.571429   1.000000        14.0  2.000000     34.04
# 2023   1.3047      41.0  5.638989   1.162455       927.0  3.346570     36.72
# 6713   7.9213      44.0  6.448113   0.978774      1057.0  2.492925     34.13
# 9840   2.4922      21.0  3.430939   0.939227       834.0  2.303867     36.61
#
#        Longitude    Price
# ...

# %%
#indepemdent and dependent features
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %% [markdown]
# ## 🎯 Separating Features from Target (X and y Explained Simply)
#
# ### 🤔 What are X and y in Machine Learning?
#
# **Simple analogy**: Think of learning to drive a car
#
# **X (Features)** = Everything you observe:
# - Speed of other cars
# - Weather conditions
# - Road signs
# - Traffic lights
#
# **y (Target)** = What you decide to do:
# - Press the gas pedal
# - Press the brake
# - Turn left or right
#
# ### 🏠 In Our Housing Example:
#
# #### **X (Features)** - House Characteristics:
# All the information ABOUT the house that might affect its price:
# - Location (latitude, longitude)
# - Size (average rooms, bedrooms)
# - Age of the house
# - Neighborhood (income, population)
#
# #### **y (Target)** - What We Want to Predict:
# - **House Price** - The thing we're trying to guess
#
# ### 🔍 Understanding the Code:
#
# ```python
# X = df.iloc[:,:-1]    # All columns EXCEPT the last one
# y = df.iloc[:,-1]     # ONLY the last column
# ```
#
# #### **Breaking Down `df.iloc[:,:-1]`**:
# - `df.iloc`: "Access data by position numbers"
# - `:`: "Take all rows"
# - `:-1`: "Take all columns except the last one"
# - **Result**: All house features (8 columns)
#
# #### **Breaking Down `df.iloc[:,-1]`**:
# - `df.iloc`: "Access data by position numbers"
# - `:`: "Take all rows"
# - `-1`: "Take only the last column"
# - **Result**: Just the prices (1 column)
#
# ### 📊 Visual Representation:
#
# ```
# Original DataFrame:
# | MedInc | HouseAge | AveRooms | ... | Longitude | Price |
# |--------|----------|----------|-----|-----------|-------|
# | 8.32   | 41.0     | 6.98     | ... | -122.23   | 4.526 |
#
# After Separation:
#
# X (Features):                           y (Target):
# | MedInc | HouseAge | AveRooms | ... |     | Price |
# |--------|----------|----------|-----|     |-------|
# | 8.32   | 41.0     | 6.98     | ... |     | 4.526 |
# ```
#
# ### 🎯 Why Separate X and y?
#
# #### **Machine Learning Process**:
# 1. **Show the computer X**: "Here are house features"
# 2. **Show the computer y**: "Here are the corresponding prices"
# 3. **Computer learns**: "Oh, bigger houses cost more!"
# 4. **Test the computer**: "Given these new house features (X), what's the price (y)?"
#
# #### **Real-World Analogy**:
# Teaching a child to recognize animals:
# - **X**: Show pictures of animals (features)
# - **y**: Tell them what animal it is (target)
# - **Learning**: Child learns to connect features to animal names
# - **Testing**: Show new picture, child guesses the animal
#
# ### 💡 Key ML Concepts:
#
# #### **Features (X)** - The Input:
# - Also called: predictors, independent variables, input variables
# - **Purpose**: Information used to make predictions
# - **Question they answer**: "What do we know about this house?"
#
# #### **Target (y)** - The Output:
# - Also called: response, dependent variable, output variable, label
# - **Purpose**: What we're trying to predict
# - **Question it answers**: "What's the price of this house?"
#
# ### 🔧 Common Mistakes Beginners Make:
#
# ❌ **Wrong**: Including price in X
# - Computer would cheat (already knows the answer)
#
# ❌ **Wrong**: Having multiple targets in y
# - Computer gets confused about what to predict
#
# ✅ **Correct**: Clear separation
# - X = everything that helps predict
# - y = the one thing we want to predict
#
# ### 🎲 Alternative Ways to Separate:
#
# ```python
# # Method 1: By position (what we used)
# X = df.iloc[:,:-1]
# y = df.iloc[:,-1]
#
# # Method 2: By column name
# X = df.drop('Price', axis=1)  # Remove price column
# y = df['Price']               # Keep only price column
#
# # Method 3: Explicit selection
# X = df[['MedInc', 'HouseAge', 'AveRooms', ...]]
# y = df['Price']
# ```
#
# **Remember**: X = "What we know", y = "What we want to predict"

# %%
X
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 545    5.5337      52.0  5.188940   0.894009      1033.0  2.380184     37.77
# 13478  3.0278      26.0  5.803347   1.158996       664.0  2.778243     34.07
# 13818  2.8021      14.0  6.239175   1.146392      1349.0  2.781443     34.43
# 8593   4.4211      44.0  5.237154   0.968379       669.0  2.644269     33.88
# 9903   5.2444      33.0  6.753363   1.052317      1776.0  2.654709     38.31
# ...       ...       ...       ...        ...         ...       ...       ...
# 12769  2.0224      41.0  4.963470   1.242009       462.0  2.109589     38.62
# 11009  8.2653       4.0  7.231265   1.021757      3754.0  3.024980     33.79
# 10790  3.5388      32.0  5.031390   1.044843       557.0  2.497758     33.63
# 5004   3.3906      48.0  5.732353   0.905882       823.0  2.420588     34.02
# 17935  3.3333      42.0  4.689769   1.089109       659.0  2.174917     37.35
#
#        Longitude
# 545      -122.27
# ...

# %%
X
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 545    5.5337      52.0  5.188940   0.894009      1033.0  2.380184     37.77
# 13478  3.0278      26.0  5.803347   1.158996       664.0  2.778243     34.07
# 13818  2.8021      14.0  6.239175   1.146392      1349.0  2.781443     34.43
# 8593   4.4211      44.0  5.237154   0.968379       669.0  2.644269     33.88
# 9903   5.2444      33.0  6.753363   1.052317      1776.0  2.654709     38.31
# ...       ...       ...       ...        ...         ...       ...       ...
# 12769  2.0224      41.0  4.963470   1.242009       462.0  2.109589     38.62
# 11009  8.2653       4.0  7.231265   1.021757      3754.0  3.024980     33.79
# 10790  3.5388      32.0  5.031390   1.044843       557.0  2.497758     33.63
# 5004   3.3906      48.0  5.732353   0.905882       823.0  2.420588     34.02
# 17935  3.3333      42.0  4.689769   1.089109       659.0  2.174917     37.35
#
#        Longitude
# 545      -122.27
# ...

# %%
y
# Out:
# 545      3.720
# 13478    0.968
# 13818    1.112
# 8593     3.240
# 9903     2.811
#          ...
# 12769    0.649
# 11009    3.740
# 10790    4.070
# 5004     1.897
# 17935    2.379
# Name: Price, Length: 8256, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor()
model
# Out:
# DecisionTreeRegressor()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_pred,y_test)
# Out:
# 0.5171300017785074

# %%
#hyperparameter tuning
parameter={
    'criterion':['squared_error','friedman_mse','absolute_error','poisson'],
    'splitter':['best','random'],
    'max_depth':[1,2,3,4,5,6,7,8,10,11,12],
    'max_features':['auto','sqrt','log2']
}
regressor=DecisionTreeRegressor()

# %%
from sklearn.model_selection import GridSearchCV
model=GridSearchCV(regressor,param_grid=parameter,cv=3,scoring='neg_mean_squared_error')

# %%
model.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=3, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_depth': [1, 2, 3, 4, 5, 6, 7, 8, 10, 11, 12],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='neg_mean_squared_error')

# %%
model.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 8,
#  'max_features': 'log2',
#  'splitter': 'best'}

# %%
final_model=DecisionTreeRegressor(criterion='squared_error',max_depth=8,max_features='log2',splitter='best')

# %%
final_model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=8, max_features='log2')

# %%
from sklearn import tree
plt.Figure(figsize=(12,10))
tree.plot_tree(final_model,filled=True)
# Out:
# [Text(0.5604363207547169, 0.9444444444444444, 'x[0] <= 5.148\nsquared_error = 1.351\nsamples = 6604\nvalue = 2.076'),
#  Text(0.3022237196765499, 0.8333333333333334, 'x[3] <= 1.12\nsquared_error = 0.864\nsamples = 5307\nvalue = 1.751'),
#  Text(0.4313300202156334, 0.8888888888888888, 'True  '),
#  Text(0.16324123989218328, 0.7222222222222222, 'x[0] <= 2.834\nsquared_error = 0.827\nsamples = 4165\nvalue = 1.802'),
#  Text(0.07850404312668463, 0.6111111111111112, 'x[2] <= 4.138\nsquared_error = 0.518\nsamples = 1482\nvalue = 1.332'),
#  Text(0.03840970350404313, 0.5, 'x[2] <= 3.539\nsquared_error = 0.661\nsamples = 623\nvalue = 1.608'),
#  Text(0.0215633423180593, 0.3888888888888889, 'x[5] <= 3.342\nsquared_error = 0.815\nsamples = 283\nvalue = 1.813'),
#  Text(0.01078167115902965, 0.2777777777777778, 'x[4] <= 1303.0\nsquared_error = 0.936\nsamples = 149\nvalue = 2.133'),
# ...

# %%
y_pred=model.predict(X_test)

# %%
r2_score(y_pred,y_test)
# Out:
# 0.4224431044164312
